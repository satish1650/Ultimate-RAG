# %%
# !pip install docling[all]
# Out:
# Collecting docling[all]
#   Downloading docling-2.81.0-py3-none-any.whl.metadata (12 kB)
# WARNING: docling 2.81.0 does not provide the extra 'all'
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from docling[all]) (2.12.3)
# Collecting docling-core<3.0.0,>=2.66.0 (from docling-core[chunking]<3.0.0,>=2.66.0->docling[all])
#   Downloading docling_core-2.70.2-py3-none-any.whl.metadata (8.1 kB)
# Collecting docling-parse<6.0.0,>=5.3.2 (from docling[all])
#   Downloading docling_parse-5.6.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (9.9 kB)
# Collecting docling-ibm-models<4,>=3.12.0 (from docling[all])
#   Downloading docling_ibm_models-3.12.0-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: torch<3.0.0,>=2.2.2 in /usr/local/lib/python3.12/dist-packages (from docling[all]) (2.10.0+cu128)
# Requirement already satisfied: torchvision<1,>=0 in /usr/local/lib/python3.12/dist-packages (from docling[all]) (0.25.0+cu128)
# Collecting filetype<2.0.0,>=1.2.0 (from docling[all])
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting pypdfium2!=4.30.1,<6.0.0,>=4.30.0 (from docling[all])
#   Downloading pypdfium2-5.6.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.1/68.1 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.3.0 in /usr/local/lib/python3.12/dist-packages (from docling[all]) (2.13.1)
# Collecting huggingface_hub<1,>=0.23 (from docling[all])
#   Downloading huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: requests<3.0.0,>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from docling[all]) (2.32.4)
# Collecting rapidocr<4.0.0,>=3.3 (from docling[all])
#   Downloading rapidocr-3.7.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: certifi>=2024.7.4 in /usr/local/lib/python3.12/dist-packages (from docling[all]) (2026.2.25)
# Requirement already satisfied: rtree<2.0.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from docling[all]) (1.4.1)
# Collecting typer<0.22.0,>=0.12.5 (from docling[all])
#   Downloading typer-0.21.2-py3-none-any.whl.metadata (16 kB)
# Collecting python-docx<2.0.0,>=1.1.2 (from docling[all])
#   Downloading python_docx-1.2.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting python-pptx<2.0.0,>=1.0.2 (from docling[all])
#   Downloading python_pptx-1.0.2-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /usr/local/lib/python3.12/dist-packages (from docling[all]) (4.13.5)
# Requirement already satisfied: pandas<4.0.0,>=2.1.4 in /usr/local/lib/python3.12/dist-packages (from docling[all]) (2.2.2)
# Collecting marko<3.0.0,>=2.1.2 (from docling[all])
#   Downloading marko-2.2.2-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: openpyxl<4.0.0,>=3.1.5 in /usr/local/lib/python3.12/dist-packages (from docling[all]) (3.1.5)
# Requirement already satisfied: lxml<7.0.0,>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from docling[all]) (6.0.2)
# Requirement already satisfied: pillow<13.0.0,>=10.0.0 in /usr/local/lib/python3.12/dist-packages (from docling[all]) (11.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.65.0 in /usr/local/lib/python3.12/dist-packages (from docling[all]) (4.67.3)
# Requirement already satisfied: pluggy<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from docling[all]) (1.6.0)
# Collecting pylatexenc<3.0,>=2.10 (from docling[all])
#   Downloading pylatexenc-2.10.tar.gz (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 8.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scipy<2.0.0,>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from docling[all]) (1.16.3)
# Requirement already satisfied: accelerate<2,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from docling[all]) (1.13.0)
# Collecting polyfactory>=2.22.2 (from docling[all])
#   Downloading polyfactory-3.3.0-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from docling[all]) (0.7.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from accelerate<2,>=1.0.0->docling[all]) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from accelerate<2,>=1.0.0->docling[all]) (26.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate<2,>=1.0.0->docling[all]) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from accelerate<2,>=1.0.0->docling[all]) (6.0.3)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from accelerate<2,>=1.0.0->docling[all]) (0.7.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4<5.0.0,>=4.12.3->docling[all]) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4<5.0.0,>=4.12.3->docling[all]) (4.15.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.16.0 in /usr/local/lib/python3.12/dist-packages (from docling-core<3.0.0,>=2.66.0->docling-core[chunking]<3.0.0,>=2.66.0->docling[all]) (4.26.0)
# Collecting jsonref<2.0.0,>=1.1.0 (from docling-core<3.0.0,>=2.66.0->docling-core[chunking]<3.0.0,>=2.66.0->docling[all])
#   Downloading jsonref-1.1.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: tabulate<0.11.0,>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from docling-core<3.0.0,>=2.66.0->docling-core[chunking]<3.0.0,>=2.66.0->docling[all]) (0.9.0)
# Collecting latex2mathml<4.0.0,>=3.77.0 (from docling-core<3.0.0,>=2.66.0->docling-core[chunking]<3.0.0,>=2.66.0->docling[all])
#   Downloading latex2mathml-3.79.0-py3-none-any.whl.metadata (15 kB)
# Collecting semchunk<4.0.0,>=2.2.0 (from docling-core[chunking]<3.0.0,>=2.66.0->docling[all])
#   Downloading semchunk-3.2.5-py3-none-any.whl.metadata (14 kB)
# Collecting tree-sitter<0.27.0,>=0.25.0 (from docling-core[chunking]<3.0.0,>=2.66.0->docling[all])
#   Downloading tree_sitter-0.25.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (10.0 kB)
# Collecting tree-sitter-python>=0.23.6 (from docling-core[chunking]<3.0.0,>=2.66.0->docling[all])
#   Downloading tree_sitter_python-0.25.0-cp310-abi3-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (1.9 kB)
# Collecting tree-sitter-c>=0.23.4 (from docling-core[chunking]<3.0.0,>=2.66.0->docling[all])
#   Downloading tree_sitter_c-0.24.1-cp310-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting tree-sitter-javascript>=0.23.1 (from docling-core[chunking]<3.0.0,>=2.66.0->docling[all])
#   Downloading tree_sitter_javascript-0.25.0-cp310-abi3-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (2.2 kB)
# Collecting tree-sitter-typescript>=0.23.2 (from docling-core[chunking]<3.0.0,>=2.66.0->docling[all])
#   Downloading tree_sitter_typescript-0.23.2-cp39-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.3 kB)
# Requirement already satisfied: transformers<6.0.0,>=4.34.0 in /usr/local/lib/python3.12/dist-packages (from docling-core[chunking]<3.0.0,>=2.66.0->docling[all]) (5.0.0)
# Collecting jsonlines<5.0.0,>=3.1.0 (from docling-ibm-models<4,>=3.12.0->docling[all])
#   Downloading jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting transformers<6.0.0,>=4.34.0 (from docling-core[chunking]<3.0.0,>=2.66.0->docling[all])
#   Downloading transformers-4.57.6-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface_hub<1,>=0.23->docling[all]) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub<1,>=0.23->docling[all]) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub<1,>=0.23->docling[all]) (1.4.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl<4.0.0,>=3.1.5->docling[all]) (2.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<4.0.0,>=2.1.4->docling[all]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<4.0.0,>=2.1.4->docling[all]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<4.0.0,>=2.1.4->docling[all]) (2025.3)
# Collecting faker>=5.0.0 (from polyfactory>=2.22.2->docling[all])
#   Downloading faker-40.11.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->docling[all]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->docling[all]) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->docling[all]) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.3.0->docling[all]) (1.2.2)
# Collecting XlsxWriter>=0.5.7 (from python-pptx<2.0.0,>=1.0.2->docling[all])
#   Downloading xlsxwriter-3.2.9-py3-none-any.whl.metadata (2.7 kB)
# Collecting pyclipper>=1.2.0 (from rapidocr<4.0.0,>=3.3->docling[all])
#   Downloading pyclipper-1.4.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (8.6 kB)
# Requirement already satisfied: opencv_python>=4.5.1.48 in /usr/local/lib/python3.12/dist-packages (from rapidocr<4.0.0,>=3.3->docling[all]) (4.13.0.92)
# Requirement already satisfied: six>=1.15.0 in /usr/local/lib/python3.12/dist-packages (from rapidocr<4.0.0,>=3.3->docling[all]) (1.17.0)
# Requirement already satisfied: Shapely!=2.0.4,>=1.7.1 in /usr/local/lib/python3.12/dist-packages (from rapidocr<4.0.0,>=3.3->docling[all]) (2.1.2)
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.12/dist-packages (from rapidocr<4.0.0,>=3.3->docling[all]) (2.3.0)
# Collecting colorlog (from rapidocr<4.0.0,>=3.3->docling[all])
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.2->docling[all]) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.2->docling[all]) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.2->docling[all]) (2.5.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->docling[all]) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->docling[all]) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->docling[all]) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->docling[all]) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->docling[all]) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->docling[all]) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->docling[all]) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->docling[all]) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->docling[all]) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->docling[all]) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->docling[all]) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->docling[all]) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->docling[all]) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->docling[all]) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->docling[all]) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->docling[all]) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->docling[all]) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->docling[all]) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->docling[all]) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->docling[all]) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->docling[all]) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch<3.0.0,>=2.2.2->docling[all]) (1.4.3)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.22.0,>=0.12.5->docling[all]) (8.3.1)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer<0.22.0,>=0.12.5->docling[all]) (0.0.4)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.22.0,>=0.12.5->docling[all]) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.22.0,>=0.12.5->docling[all]) (13.9.4)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonlines<5.0.0,>=3.1.0->docling-ibm-models<4,>=3.12.0->docling[all]) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.16.0->docling-core<3.0.0,>=2.66.0->docling-core[chunking]<3.0.0,>=2.66.0->docling[all]) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.16.0->docling-core<3.0.0,>=2.66.0->docling-core[chunking]<3.0.0,>=2.66.0->docling[all]) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.16.0->docling-core<3.0.0,>=2.66.0->docling-core[chunking]<3.0.0,>=2.66.0->docling[all]) (0.30.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<0.22.0,>=0.12.5->docling[all]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<0.22.0,>=0.12.5->docling[all]) (2.19.2)
# Collecting mpire[dill] (from semchunk<4.0.0,>=2.2.0->docling-core[chunking]<3.0.0,>=2.66.0->docling[all])
#   Downloading mpire-2.10.2-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3.0.0,>=2.2.2->docling[all]) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.34.0->docling-core[chunking]<3.0.0,>=2.66.0->docling[all]) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.34.0->docling-core[chunking]<3.0.0,>=2.66.0->docling[all]) (0.22.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3.0.0,>=2.2.2->docling[all]) (3.0.3)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from omegaconf->rapidocr<4.0.0,>=3.3->docling[all]) (4.9.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<0.22.0,>=0.12.5->docling[all]) (0.1.2)
# Requirement already satisfied: multiprocess>=0.70.15 in /usr/local/lib/python3.12/dist-packages (from mpire[dill]->semchunk<4.0.0,>=2.2.0->docling-core[chunking]<3.0.0,>=2.66.0->docling[all]) (0.70.16)
# Requirement already satisfied: dill>=0.3.8 in /usr/local/lib/python3.12/dist-packages (from multiprocess>=0.70.15->mpire[dill]->semchunk<4.0.0,>=2.2.0->docling-core[chunking]<3.0.0,>=2.66.0->docling[all]) (0.3.8)
# Downloading docling_core-2.70.2-py3-none-any.whl (266 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.7/266.7 kB 15.1 MB/s eta 0:00:00
# Downloading docling_ibm_models-3.12.0-py3-none-any.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.8/93.8 kB 6.9 MB/s eta 0:00:00
# Downloading docling_parse-5.6.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 52.0 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 43.4 MB/s eta 0:00:00
# Downloading marko-2.2.2-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.7/42.7 kB 5.1 MB/s eta 0:00:00
# Downloading polyfactory-3.3.0-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 4.0 MB/s eta 0:00:00
# Downloading pypdfium2-5.6.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 81.9 MB/s eta 0:00:00
# Downloading python_docx-1.2.0-py3-none-any.whl (252 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 28.1 MB/s eta 0:00:00
# Downloading python_pptx-1.0.2-py3-none-any.whl (472 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.8/472.8 kB 24.2 MB/s eta 0:00:00
# Downloading rapidocr-3.7.0-py3-none-any.whl (15.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 78.9 MB/s eta 0:00:00
# Downloading typer-0.21.2-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.7/56.7 kB 3.4 MB/s eta 0:00:00
# Downloading docling-2.81.0-py3-none-any.whl (423 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.3/423.3 kB 37.0 MB/s eta 0:00:00
# Downloading faker-40.11.0-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 76.4 MB/s eta 0:00:00
# Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Downloading jsonref-1.1.0-py3-none-any.whl (9.4 kB)
# Downloading latex2mathml-3.79.0-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.9/73.9 kB 6.5 MB/s eta 0:00:00
# Downloading pyclipper-1.4.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (978 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 978.2/978.2 kB 55.6 MB/s eta 0:00:00
# Downloading semchunk-3.2.5-py3-none-any.whl (13 kB)
# Downloading transformers-4.57.6-py3-none-any.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 74.3 MB/s eta 0:00:00
# Downloading tree_sitter-0.25.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (635 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 635.4/635.4 kB 54.3 MB/s eta 0:00:00
# Downloading tree_sitter_c-0.24.1-cp310-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (98 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.1/98.1 kB 12.4 MB/s eta 0:00:00
# Downloading tree_sitter_javascript-0.25.0-cp310-abi3-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.7/99.7 kB 13.5 MB/s eta 0:00:00
# Downloading tree_sitter_python-0.25.0-cp310-abi3-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (108 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.1/108.1 kB 14.3 MB/s eta 0:00:00
# Downloading tree_sitter_typescript-0.23.2-cp39-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (344 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.0/345.0 kB 33.7 MB/s eta 0:00:00
# Downloading xlsxwriter-3.2.9-py3-none-any.whl (175 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.3/175.3 kB 22.5 MB/s eta 0:00:00
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Downloading mpire-2.10.2-py3-none-any.whl (272 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 272.8/272.8 kB 23.8 MB/s eta 0:00:00
# Building wheels for collected packages: pylatexenc
#   Building wheel for pylatexenc (setup.py) ... done
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136817 sha256=d6420b3550731c471a29f7856ba9a44a3c1e68ae88dfa4ad4b271f69f6881bd3
#   Stored in directory: /root/.cache/pip/wheels/06/3e/78/fa1588c1ae991bbfd814af2bcac6cef7a178beee1939180d46
# Successfully built pylatexenc
# Installing collected packages: pylatexenc, filetype, XlsxWriter, tree-sitter-typescript, tree-sitter-python, tree-sitter-javascript, tree-sitter-c, tree-sitter, python-docx, pypdfium2, pyclipper, mpire, marko, latex2mathml, jsonref, jsonlines, faker, colorlog, rapidocr, python-pptx, polyfactory, huggingface_hub, typer, semchunk, transformers, docling-core, docling-parse, docling-ibm-models, docling
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface_hub 1.7.1
#     Uninstalling huggingface_hub-1.7.1:
#       Successfully uninstalled huggingface_hub-1.7.1
#   Attempting uninstall: typer
#     Found existing installation: typer 0.24.1
#     Uninstalling typer-0.24.1:
#       Successfully uninstalled typer-0.24.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.0.0
#     Uninstalling transformers-5.0.0:
#       Successfully uninstalled transformers-5.0.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# typer-slim 0.24.0 requires typer>=0.24.0, but you have typer 0.21.2 which is incompatible.
# Successfully installed XlsxWriter-3.2.9 colorlog-6.10.1 docling-2.81.0 docling-core-2.70.2 docling-ibm-models-3.12.0 docling-parse-5.6.0 faker-40.11.0 filetype-1.2.0 huggingface_hub-0.36.2 jsonlines-4.0.0 jsonref-1.1.0 latex2mathml-3.79.0 marko-2.2.2 mpire-2.10.2 polyfactory-3.3.0 pyclipper-1.4.0 pylatexenc-2.10 pypdfium2-5.6.0 python-docx-1.2.0 python-pptx-1.0.2 rapidocr-3.7.0 semchunk-3.2.5 transformers-4.57.6 tree-sitter-0.25.2 tree-sitter-c-0.24.1 tree-sitter-javascript-0.25.0 tree-sitter-python-0.25.0 tree-sitter-typescript-0.23.2 typer-0.21.2

# %%
# !docling --to html --to md --pipeline vlm --vlm-model granite_docling "https://arxiv.org/pdf/2501.17887"
# Out:
# 2026-03-22 05:52:09.642827: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774158729.663286    2551 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774158729.670009    2551 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1774158729.687144    2551 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774158729.687168    2551 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774158729.687172    2551 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774158729.687175    2551 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-03-22 05:52:09.691701: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Prerequisites:
# pip install torch
# pip install docling_core
# pip install transformers

import torch
from docling_core.types.doc import DoclingDocument
from docling_core.types.doc.document import DocTagsDocument
from transformers import AutoProcessor, AutoModelForVision2Seq
from transformers.image_utils import load_image
from pathlib import Path

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# Load images
image = load_image("https://huggingface.co/ibm-granite/granite-docling-258M/resolve/main/assets/new_arxiv.png")

# Initialize processor and model
processor = AutoProcessor.from_pretrained("ibm-granite/granite-docling-258M")
model = AutoModelForVision2Seq.from_pretrained(
    "ibm-granite/granite-docling-258M",
    torch_dtype=torch.bfloat16,
    _attn_implementation="sdpa", # Changed to sdpa to avoid FlashAttention2 dependency
).to(DEVICE)

# Create input messages
messages = [
    {
        "role": "user",
        "content": [
            {"type": "image"},
            {"type": "text", "text": "Convert this page to docling."}
        ]
    },
]

# Prepare inputs
prompt = processor.apply_chat_template(messages, add_generation_prompt=True)
inputs = processor(text=prompt, images=[image], return_tensors="pt")
inputs = inputs.to(DEVICE)

# Generate outputs
generated_ids = model.generate(**inputs, max_new_tokens=8192)
prompt_length = inputs.input_ids.shape[1]
trimmed_generated_ids = generated_ids[:, prompt_length:]
doctags = processor.batch_decode(
    trimmed_generated_ids,
    skip_special_tokens=False,
)[0].lstrip()

print(f"DocTags: \n{doctags}\n")


# Populate document
doctags_doc = DocTagsDocument.from_doctags_and_image_pairs([doctags], [image])
# create a docling document
doc = DoclingDocument.load_from_doctags(doctags_doc, document_name="Document")
print(f"Markdown:\n{doc.export_to_markdown()}\n")

## export as any format.
# Path("out/").mkdir(parents=True, exist_ok=True)
# HTML:
# output_path_html = Path("out/") / "example.html"
# doc.save_as_html(output_path_html)
# Markdown:
# output_path_md = Path("out/") / "example.md"
# doc.save_as_markdown(output_path_md)

# %%
# Prerequisites:
# pip install vllm
# pip install docling_core
# place page images you want to convert into "img/" dir

import time
import os
from vllm import LLM, SamplingParams
from transformers import AutoProcessor
from PIL import Image
from docling_core.types.doc import DoclingDocument
from docling_core.types.doc.document import DocTagsDocument
from pathlib import Path

# Configuration
MODEL_PATH = "ibm-granite/granite-docling-258M"
IMAGE_DIR = "img/"  # Place your page images here
OUTPUT_DIR = "out/"
PROMPT_TEXT = "Convert this page to docling."

messages = [
    {
        "role": "user",
        "content": [
            {"type": "image"},
            {"type": "text", "text": PROMPT_TEXT},
        ],
    },
]


# Ensure output directory exists
os.makedirs(OUTPUT_DIR, exist_ok=True)

# Initialize LLM
llm = LLM(model=MODEL_PATH, revision="untied", limit_mm_per_prompt={"image": 1})
processor = AutoProcessor.from_pretrained(MODEL_PATH)

sampling_params = SamplingParams(
    temperature=0.0,
    max_tokens=8192,
    skip_special_tokens=False,
)

# Load and prepare all images and prompts up front
batched_inputs = []
image_names = []

for img_file in sorted(os.listdir(IMAGE_DIR)):
    if img_file.lower().endswith((".png", ".jpg", ".jpeg")):
        img_path = os.path.join(IMAGE_DIR, img_file)
        with Image.open(img_path) as im:
            image = im.convert("RGB")

        prompt = processor.apply_chat_template(messages, add_generation_prompt=True)
        batched_inputs.append({"prompt": prompt, "multi_modal_data": {"image": image}})
        image_names.append(os.path.splitext(img_file)[0])

# Run batch inference
start_time = time.time()
outputs = llm.generate(batched_inputs, sampling_params=sampling_params)

# Postprocess all results
for img_fn, output, input_data in zip(image_names, outputs, batched_inputs):
    doctags = output.outputs[0].text
    output_path_dt = Path(OUTPUT_DIR) / f"{img_fn}.dt"
    output_path_md = Path(OUTPUT_DIR) / f"{img_fn}.md"

    with open(output_path_dt, "w", encoding="utf-8") as f:
        f.write(doctags)

    # Convert to DoclingDocument and save markdown
    doctags_doc = DocTagsDocument.from_doctags_and_image_pairs([doctags], [input_data["multi_modal_data"]["image"]])
    doc = DoclingDocument.load_from_doctags(doctags_doc, document_name="Document")
    doc.save_as_markdown(output_path_md)

print(f"Total time: {time.time() - start_time:.2f} sec")

# %%
from transformers import AutoProcessor, AutoModelForVision2Seq
from huggingface_hub import hf_hub_download
import torch

device = "cuda" if torch.cuda.is_available() else "cpu"

model_path = "ibm-granite/granite-vision-3.3-2b"
processor = AutoProcessor.from_pretrained(model_path)
model = AutoModelForVision2Seq.from_pretrained(model_path).to(device)

# prepare image and text prompt, using the appropriate prompt template

img_path = hf_hub_download(repo_id=model_path, filename='/content/testimage.png')

conversation = [
    {
        "role": "user",
        "content": [
            {"type": "image", "url": img_path},
            {"type": "text", "text": "What is the version of MinerU?"},
        ],
    },
]
inputs = processor.apply_chat_template(
    conversation,
    add_generation_prompt=True,
    tokenize=True,
    return_dict=True,
    return_tensors="pt"
).to(device)


# autoregressively complete prompt
output = model.generate(**inputs, max_new_tokens=100)
print(processor.decode(output[0], skip_special_tokens=True))
# Out:
# /usr/local/lib/python3.12/dist-packages/transformers/models/auto/modeling_auto.py:2284: FutureWarning: The class `AutoModelForVision2Seq` is deprecated and will be removed in v5.0. Please use `AutoModelForImageTextToText` instead.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
from docling.document_converter import DocumentConverter, PdfFormatOption
from docling.datamodel.pipeline_options import PdfPipelineOptions
from docling.datamodel.base_models import InputFormat

# ── Configure the standard pipeline ──────────────────────────────────────
pipeline_options = PdfPipelineOptions(
    do_layout=True,           # DocLayNet: layout segmentation
    do_table_structure=True,  # TableFormer: table parsing
    do_ocr=True,              # EasyOCR / Tesseract fallback for scanned pages
    generate_page_images=True,
    do_formula_enrichment=True,
    generate_picture_images=True,
)

# ── Build the converter ───────────────────────────────────────────────────
converter = DocumentConverter(
    format_options={
        InputFormat.PDF: PdfFormatOption(
            pipeline_options=pipeline_options
        )
    }
)

# ── Run on your arXiv PDF ─────────────────────────────────────────────────
source = "https://arxiv.org/pdf/2501.17887"
result = converter.convert(source)

# ── Export to Markdown ────────────────────────────────────────────────────
markdown_output = result.document.export_to_markdown()
with open("output.md", "w") as f:
    f.write(markdown_output)

# ── Export to HTML ────────────────────────────────────────────────────────
html_output = result.document.export_to_html()
with open("output.html", "w") as f:
    f.write(html_output)

print("✅ Done — DocLayNet + TableFormer pipeline")
# Out:
# [INFO] 2026-03-20 10:01:22,230 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-03-20 10:01:22,238 [RapidOCR] device_config.py:64: Using GPU device with ID: 0
# [INFO] 2026-03-20 10:01:22,242 [RapidOCR] download_file.py:68: Initiating download: https://www.modelscope.cn/models/RapidAI/RapidOCR/resolve/v3.7.0/torch/PP-OCRv4/det/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-03-20 10:01:23,158 [RapidOCR] download_file.py:82: Download size: 13.83MB
# [INFO] 2026-03-20 10:01:23,370 [RapidOCR] download_file.py:95: Successfully saved to: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-03-20 10:01:23,373 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-03-20 10:01:23,767 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-03-20 10:01:23,768 [RapidOCR] device_config.py:64: Using GPU device with ID: 0
# [INFO] 2026-03-20 10:01:23,771 [RapidOCR] download_file.py:68: Initiating download: https://www.modelscope.cn/models/RapidAI/RapidOCR/resolve/v3.7.0/torch/PP-OCRv4/cls/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-03-20 10:01:24,528 [RapidOCR] download_file.py:82: Download size: 0.56MB
# [INFO] 2026-03-20 10:01:24,541 [RapidOCR] download_file.py:95: Successfully saved to: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-03-20 10:01:24,542 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-03-20 10:01:24,631 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-03-20 10:01:24,632 [RapidOCR] device_config.py:64: Using GPU device with ID: 0
# [INFO] 2026-03-20 10:01:24,634 [RapidOCR] download_file.py:68: Initiating download: https://www.modelscope.cn/models/RapidAI/RapidOCR/resolve/v3.7.0/torch/PP-OCRv4/rec/ch_PP-OCRv4_rec_infer.pth
# [INFO] 2026-03-20 10:01:25,395 [RapidOCR] download_file.py:82: Download size: 25.67MB
# [INFO] 2026-03-20 10:01:25,678 [RapidOCR] download_file.py:95: Successfully saved to: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# [INFO] 2026-03-20 10:01:25,679 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# ✅ Done — DocLayNet + TableFormer pipeline

# %%
# !pip install docling_core
# Out:
# Requirement already satisfied: docling_core in /usr/local/lib/python3.12/dist-packages (2.70.2)
# Requirement already satisfied: jsonschema<5.0.0,>=4.16.0 in /usr/local/lib/python3.12/dist-packages (from docling_core) (4.26.0)
# Requirement already satisfied: pydantic!=2.10.0,!=2.10.1,!=2.10.2,<3.0.0,>=2.6.0 in /usr/local/lib/python3.12/dist-packages (from docling_core) (2.12.3)
# Requirement already satisfied: jsonref<2.0.0,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from docling_core) (1.1.0)
# Requirement already satisfied: tabulate<0.11.0,>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from docling_core) (0.9.0)
# Requirement already satisfied: pandas<4.0.0,>=2.1.4 in /usr/local/lib/python3.12/dist-packages (from docling_core) (2.2.2)
# Requirement already satisfied: pillow<13.0.0,>=10.0.0 in /usr/local/lib/python3.12/dist-packages (from docling_core) (11.3.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.1 in /usr/local/lib/python3.12/dist-packages (from docling_core) (6.0.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.12.2 in /usr/local/lib/python3.12/dist-packages (from docling_core) (4.15.0)
# Requirement already satisfied: typer<0.25.0,>=0.12.5 in /usr/local/lib/python3.12/dist-packages (from docling_core) (0.21.2)
# Requirement already satisfied: latex2mathml<4.0.0,>=3.77.0 in /usr/local/lib/python3.12/dist-packages (from docling_core) (3.79.0)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from docling_core) (0.7.1)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.16.0->docling_core) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.16.0->docling_core) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.16.0->docling_core) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.16.0->docling_core) (0.30.0)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas<4.0.0,>=2.1.4->docling_core) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<4.0.0,>=2.1.4->docling_core) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<4.0.0,>=2.1.4->docling_core) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<4.0.0,>=2.1.4->docling_core) (2025.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=2.10.0,!=2.10.1,!=2.10.2,<3.0.0,>=2.6.0->docling_core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic!=2.10.0,!=2.10.1,!=2.10.2,<3.0.0,>=2.6.0->docling_core) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic!=2.10.0,!=2.10.1,!=2.10.2,<3.0.0,>=2.6.0->docling_core) (0.4.2)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.25.0,>=0.12.5->docling_core) (8.3.1)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer<0.25.0,>=0.12.5->docling_core) (0.0.4)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.25.0,>=0.12.5->docling_core) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.25.0,>=0.12.5->docling_core) (13.9.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<4.0.0,>=2.1.4->docling_core) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<0.25.0,>=0.12.5->docling_core) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<0.25.0,>=0.12.5->docling_core) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<0.25.0,>=0.12.5->docling_core) (0.1.2)

# %%
import docling_core
import subprocess
result = subprocess.run(
    ["grep", "-r", "ImageRefMode", docling_core.__path__[0]],
    capture_output=True, text=True
)
print(result.stdout)
# Out:
# /usr/local/lib/python3.12/dist-packages/docling_core/transforms/chunker/hierarchical_chunker.py:from docling_core.types.doc.base import ImageRefMode
# /usr/local/lib/python3.12/dist-packages/docling_core/transforms/chunker/hierarchical_chunker.py:        image_mode=ImageRefMode.PLACEHOLDER,
# /usr/local/lib/python3.12/dist-packages/docling_core/transforms/serializer/latex.py:from docling_core.types.doc.base import ImageRefMode
# /usr/local/lib/python3.12/dist-packages/docling_core/transforms/serializer/latex.py:    image_mode: ImageRefMode = ImageRefMode.PLACEHOLDER
# /usr/local/lib/python3.12/dist-packages/docling_core/transforms/serializer/latex.py:        image_mode: ImageRefMode,
# /usr/local/lib/python3.12/dist-packages/docling_core/transforms/serializer/latex.py:        if image_mode == ImageRefMode.PLACEHOLDER:
# /usr/local/lib/python3.12/dist-packages/docling_core/transforms/serializer/latex.py:        elif image_mode == ImageRefMode.REFERENCED:
# /usr/local/lib/python3.12/dist-packages/docling_core/transforms/serializer/html.py:from docling_core.types.doc.base import ImageRefMode
# /usr/local/lib/python3.12/dist-packages/docling_core/transforms/serializer/html.py:    image_mode: ImageRefMode = ImageRefMode.PLACEHOLDER
# /usr/local/lib/python3.12/dist-packages/docling_core/transforms/serializer/html.py:        image_mode: ImageRefMode,
# /usr/local/lib/python3.12/dist-packages/docling_core/transforms/serializer/html.py:            and image_mode == ImageRefMode.EMBEDDED
# /usr/local/lib/python3.12/dist-packages/docling_core/transforms/serializer/html.py:                if image_mode == ImageRefMode.EMBEDDED and len(item.prov) > 0 and img_fallback:
# /usr/local/lib/python3.12/dist-packages/docling_core/transforms/serializer/html.py:            if params.image_mode == ImageRefMode.EMBEDDED:
# /usr/local/lib/python3.12/dist-packages/docling_core/transforms/serializer/html.py:            elif params.image_mode == ImageRefMode.REFERENCED:
# /usr/local/lib/python3.12/dist-packages/docling_core/transforms/serializer/markdown.py:from docling_core.types.doc.base import ImageRefMode
# /usr/local/lib/python3.12/dist-packages/docling_core/transforms/serializer/markdown.py:    image_mode: ImageRefMode = ImageRefMode.PLACEHOLDER
# /usr/local/lib/python3.12/dist-packages/docling_core/transforms/serializer/markdown.py:        image_mode: ImageRefMode,
# /usr/local/lib/python3.12/dist-packages/docling_core/transforms/serializer/markdown.py:        if image_mode == ImageRefMode.PLACEHOLDER:
# /usr/local/lib/python3.12/dist-packages/docling_core/transforms/serializer/markdown.py:        elif image_mode == ImageRefMode.EMBEDDED:
# /usr/local/lib/python3.12/dist-packages/docling_core/transforms/serializer/markdown.py:        elif image_mode == ImageRefMode.REFERENCED:
# /usr/local/lib/python3.12/dist-packages/docling_core/cli/view.py:from docling_core.types.doc.base import ImageRefMode
# /usr/local/lib/python3.12/dist-packages/docling_core/cli/view.py:        image_mode=ImageRefMode.EMBEDDED,
# /usr/local/lib/python3.12/dist-packages/docling_core/types/doc/__init__.py:from .base import BoundingBox, CoordOrigin, ImageRefMode, Size
# /usr/local/lib/python3.12/dist-packages/docling_core/types/doc/page.py:    ImageRefMode,
# /usr/local/lib/python3.12/dist-packages/docling_core/types/doc/page.py:    mode: ImageRefMode = ImageRefMode.PLACEHOLDER
# /usr/local/lib/python3.12/dist-packages/docling_core/types/doc/base.py:class ImageRefMode(str, Enum):
# /usr/local/lib/python3.12/dist-packages/docling_core/types/doc/base.py:    """ImageRefMode."""
# /usr/local/lib/python3.12/dist-packages/docling_core/types/doc/document.py:    ImageRefMode,
# /usr/local/lib/python3.12/dist-packages/docling_core/types/doc/document.py:        image_mode: ImageRefMode = ImageRefMode.EMBEDDED,
# /usr/local/lib/python3.12/dist-packages/docling_core/types/doc/document.py:        image_mode: ImageRefMode = ImageRefMode.PLACEHOLDER,
# /usr/local/lib/python3.12/dist-packages/docling_core/types/doc/document.py:        image_mode: ImageRefMode = ImageRefMode.EMBEDDED,
# /usr/local/lib/python3.12/dist-packages/docling_core/types/doc/document.py:        if image_mode == ImageRefMode.REFERENCED:
# /usr/local/lib/python3.12/dist-packages/docling_core/types/doc/document.py:        image_mode: ImageRefMode = ImageRefMode.EMBEDDED,
# /usr/local/lib/python3.12/dist-packages/docling_core/types/doc/document.py:        if image_mode == ImageRefMode.REFERENCED:
# /usr/local/lib/python3.12/dist-packages/docling_core/types/doc/document.py:        image_mode: ImageRefMode = ImageRefMode.PLACEHOLDER,
# /usr/local/lib/python3.12/dist-packages/docling_core/types/doc/document.py:        if image_mode == ImageRefMode.REFERENCED:
# /usr/local/lib/python3.12/dist-packages/docling_core/types/doc/document.py:        image_mode: ImageRefMode = ImageRefMode.PLACEHOLDER,
# /usr/local/lib/python3.12/dist-packages/docling_core/types/doc/document.py:            markdown. (Default value = ImageRefMode.PLACEHOLDER).
# /usr/local/lib/python3.12/dist-packages/docling_core/types/doc/document.py:        :type image_mode: ImageRefMode = ImageRefMode.PLACEHOLDER
# /usr/local/lib/python3.12/dist-packages/docling_core/types/doc/document.py:        image_mode: ImageRefMode = ImageRefMode.PLACEHOLDER,
# /usr/local/lib/python3.12/dist-packages/docling_core/types/doc/document.py:        if image_mode == ImageRefMode.REFERENCED:
# /usr/local/lib/python3.12/dist-packages/docling_core/types/doc/document.py:        image_mode: ImageRefMode,
# /usr/local/lib/python3.12/dist-packages/docling_core/types/doc/document.py:        if image_mode == ImageRefMode.PLACEHOLDER:
# /usr/local/lib/python3.12/dist-packages/docling_core/types/doc/document.py:        elif image_mode == ImageRefMode.REFERENCED:
# /usr/local/lib/python3.12/dist-packages/docling_core/types/doc/document.py:        elif image_mode == ImageRefMode.EMBEDDED:
# /usr/local/lib/python3.12/dist-packages/docling_core/types/doc/document.py:            raise ValueError("Unsupported ImageRefMode")
# /usr/local/lib/python3.12/dist-packages/docling_core/types/doc/document.py:        image_mode: ImageRefMode = ImageRefMode.PLACEHOLDER,
# /usr/local/lib/python3.12/dist-packages/docling_core/experimental/doclang.py:from docling_core.types.doc.base import CoordOrigin, ImageRefMode
# /usr/local/lib/python3.12/dist-packages/docling_core/experimental/doclang.py:    image_mode: ImageRefMode = ImageRefMode.PLACEHOLDER
# /usr/local/lib/python3.12/dist-packages/docling_core/experimental/doclang.py:            if params.image_mode in [ImageRefMode.REFERENCED, ImageRefMode.EMBEDDED] and item.image and item.image.uri:
# /usr/local/lib/python3.12/dist-packages/docling_core/experimental/doclang.py:            elif params.image_mode == ImageRefMode.EMBEDDED and (img := item.get_image(doc)):

# %% [markdown]
# ## What each model actually does
# ```
# Your PDF
#     │
#     ▼
# ┌─────────────────────────────────────────────────────┐
# │  DocLayNet  (layout segmentation)                   │
# │  → Classifies page regions:                         │
# │    Text / Title / Table / Figure / List / Formula   │
# └──────────────────────┬──────────────────────────────┘
#                        │
#           ┌────────────┴────────────┐
#           ▼                         ▼
# ┌──────────────────┐     ┌─────────────────────────┐
# │  OCR Engine      │     │  TableFormer             │
# │  (EasyOCR /      │     │  → Reconstructs rows,    │
# │   Tesseract)     │     │    columns, merged cells │
# │  for scanned     │     │    → outputs HTML table  │
# │  pages           │     └─────────────────────────┘
# └──────────────────┘
#           │
#           ▼
# ┌─────────────────────────────────────────────────────┐
# │  Structured DoclingDocument                         │
# │  → .export_to_markdown()                            │
# │  → .export_to_html()                                │
# │  → .export_to_dict() / JSON                         │
# └─────────────────────────────────────────────────────┘

# %%
from docling.document_converter import DocumentConverter, PdfFormatOption
from docling.datamodel.pipeline_options import PdfPipelineOptions
from docling.datamodel.base_models import InputFormat
from docling_core.types.doc.base import ImageRefMode  # ✅ confirmed correct

pipeline_options = PdfPipelineOptions(
    do_layout=True,
    do_table_structure=True,
    do_ocr=False,
    do_formula_enrichment=True,
    generate_page_images=True,
    generate_picture_images=True,
    images_scale=2.0,
)

converter = DocumentConverter(
    format_options={
        InputFormat.PDF: PdfFormatOption(pipeline_options=pipeline_options)
    }
)

result = converter.convert("https://arxiv.org/pdf/2501.17887")

# ── HTML with embedded images ──────────────────────────────────────────────
html_output = result.document.export_to_html(
    image_mode=ImageRefMode.EMBEDDED
)
with open("output_with_images.html", "w") as f:
    f.write(html_output)

# ── Markdown with embedded images ──────────────────────────────────────────
md_output = result.document.export_to_markdown(
    image_mode=ImageRefMode.EMBEDDED
)
with open("output_with_images.md", "w") as f:
    f.write(md_output)

print("✅ Done")
# Out:
# ✅ Done

# %% [markdown]
# Key difference vs your current setup
#
# VLM mode (what you had)| Standard Pipeline (recommended)Layout detectionGranite-Docling 258M (one-shot)DocLayNet (dedicated model)Table parsingInferred by VLMTableFormer (specialized)Formula handlingWeakBetter with do_formula_enrichment=TrueSpeedFasterSlower but far more accurateGPU neededYesNo — CPU works fine
